# %% [markdown]
# ## **Unsupervised Learning: PCA (BaskinRobbins dataset)**
# Baskin Robbins nutritional information from
# * http://www.baskinrobbins.ca/nutritional-information/

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('f-LSQI4rgtk', width=720, height=405)
# Out:
#         <iframe
#             width="720"
#             height="405"
#             src="https://www.youtube.com/embed/f-LSQI4rgtk"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
print(f'pandas  version = {pd.__version__}')
print(f'numpy   version = {np.__version__}')
print(f'seaborn version = {sns.__version__}')
# Out:
# pandas  version = 1.1.5
# numpy   version = 1.19.5
# seaborn version = 0.11.1

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/BaskinRobbinsCluster.csv')
df.sample(10)
# Out:
#                         Flavour  Calories  ...  Protein (g)  cluster
# 39                Nutty Coconut       280  ...          6.0        1
# 24        German Chocolate Cake       190  ...          4.0        0
# 49           Pumpkin Cheesecake       160  ...          3.0        0
# 19             Cookies ‘n Cream       270  ...          5.0        1
# 40   Old Fashioned Butter Pecan       260  ...          5.0        1
# 51      Raspberry Cheese Louise       220  ...          5.0        1
# 33                 Mango Sorbet        70  ...          0.0        2
# 13  Chocolate Chip Cookie Dough       280  ...          5.0        1
# 3      Blackberry Frozen Yogurt       120  ...          3.0        0
# 29              Love Potion #31       260  ...          4.0        1
#
# [10 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Flavour            70 non-null     object
#  1   Calories           70 non-null     int64
#  2   Total Fat (g)      70 non-null     float64
#  3   Trans Fat (g)      70 non-null     float64
#  4   Carbohydrates (g)  70 non-null     int64
#  5   Sugars (g)         70 non-null     int64
#  6   Protein (g)        70 non-null     float64
#  7   cluster            70 non-null     int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 4.5+ KB

# %%
df.columns
# Out:
# Index(['Flavour', 'Calories', 'Total Fat (g)', 'Trans Fat (g)',
#        'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)', 'cluster'],
#       dtype='object')

# %%
cols=['Calories', 'Total Fat (g)', 'Trans Fat (g)',
       'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)']

# %%
df[cols].hist(layout=(1, len(cols)), figsize=(3 * len(cols), 3.5));

# %%
dcorr=df[cols].corr()
# dcorr

mask = np.zeros_like(dcorr)
# mask.shape
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(7,5)) 
sns.heatmap(dcorr, cmap=sns.diverging_palette(10, 145, n=100), 
            vmin=-1, vmax=1, center=0, linewidths=1, annot=True, mask=mask, ax=ax);

# %%
# sns.pairplot(df, vars=cols, 
#              hue='cluster',
#              plot_kws={'alpha': .4});

# %% [markdown]
# ## **PCA**

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
X=df[cols]
scaler = StandardScaler()
X_t=scaler.fit_transform(X)

# %%
X_t[:5].round(4)
# Out:
# array([[-0.5182, -0.3248, -0.5335, -0.5358, -0.2048, -0.94  ],
#        [-0.5182, -0.1981, -0.5335, -0.7206, -0.8767, -0.3402],
#        [-0.3548, -0.1981,  0.1581, -0.3511, -0.4287, -0.3402],
#        [-1.1718, -0.8318, -1.2251, -1.0902, -0.2048, -0.3402],
#        [-1.0084, -1.0852, -1.2251,  0.5728,  0.6911, -0.94  ]])

# %%
def scree_plot(X, n_components, with_cumulative=False, show_data_label=False, figsize=(10, 7)):
    '''
    PCA scree plot with cumulative
    '''
    scaler = StandardScaler()
    X_t=scaler.fit_transform(X)

    max_components = min(X.shape)
    x=np.arange(1, n_components+1)
    pca = PCA(n_components=max_components)
    pca.fit_transform(X_t)
    y1=pca.explained_variance_ratio_[:n_components]
    y2=np.cumsum(pca.explained_variance_ratio_)[:n_components]
    
    plt.figure(figsize=figsize)
    
    if n_components > 20:
        marker = None
    else:
        marker = 'o'
    if with_cumulative:
        plt.plot(x, y2, linestyle='--', marker=marker, label='cumulative', color='salmon')
        
    plt.plot(x, y1, linestyle='-', marker=marker, label='individual', color='deepskyblue')
    plt.title('explained variance ratio')
    plt.xlabel('# of components')
    plt.ylabel('proportion of variance explained')
    plt.legend()
    if with_cumulative:
        [plt.axhline(y=xl, color='.7', linestyle='--') for xl in [.8, .9, .95, 1]]
    plt.grid(axis='x')

    if show_data_label:
        for n, v, cv in zip(np.nditer(x, flags=['refs_ok']), 
                            np.nditer(y1, flags=['refs_ok']),
                            np.nditer(y2, flags=['refs_ok'])):
                plt.text(n+.02, v+.02, f'{v*100:.2f}%', fontsize=10)
                if with_cumulative:
                    plt.text(n+.02, cv+.02, f'{cv*100:.2f}%', fontsize=10)

# %%
scree_plot(X, 4, True, True, figsize=(12, 7))

# %%
# pca = PCA(n_components=X.shape[1])
pca = PCA(n_components=3)

pca.fit_transform(X_t)
print(f'explained_variance (n_components={pca.n_components}) = {pca.explained_variance_}')
print(f'explained_variance_ratio (n_components={pca.n_components}) = {pca.explained_variance_ratio_}')
print(f'sum explained_variance_ratio = {np.sum(pca.explained_variance_ratio_)}')
# Out:
# explained_variance (n_components=3) = [3.81959142 1.13428279 0.47899446]
# explained_variance_ratio (n_components=3) = [0.62750431 0.18634646 0.07869195]
# sum explained_variance_ratio = 0.8925427102383179

# %%
pca.components_.round(4) # Eigenvectors
# Out:
# array([[-0.5028, -0.3847, -0.4397, -0.3386, -0.3263, -0.4299],
#        [ 0.0436,  0.4067,  0.2583, -0.5848, -0.605 ,  0.2407],
#        [ 0.0303, -0.3411, -0.2392,  0.4553, -0.5433,  0.5683]])

# %%
cols
# Out:
# ['Calories',
#  'Total Fat (g)',
#  'Trans Fat (g)',
#  'Carbohydrates (g)',
#  'Sugars (g)',
#  'Protein (g)']

# %%
dpc=pd.DataFrame(pca.components_.T, 
                  index=cols,
                  columns=[f'PC{n+1}' for n in range(pca.n_components)]).round(4) #Eigenvectors
dpc
# Out:
#                       PC1     PC2     PC3
# Calories          -0.5028  0.0436  0.0303
# Total Fat (g)     -0.3847  0.4067 -0.3411
# Trans Fat (g)     -0.4397  0.2583 -0.2392
# Carbohydrates (g) -0.3386 -0.5848  0.4553
# Sugars (g)        -0.3263 -0.6050 -0.5433
# Protein (g)       -0.4299  0.2407  0.5683

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(dpc, cmap=sns.diverging_palette(10, 145, n=100), linewidths=1, 
            center=0, annot=True, fmt='.2f', vmin=-1, vmax=1, square=True, ax=ax);

# %%
X_pca=pca.transform(X_t)[:5] # get reduced dimensions
X_pca
# Out:
# array([[ 1.27240098, -0.08152447, -0.44421778],
#        [ 1.24760651,  0.6289527 ,  0.13436957],
#        [ 0.59008376,  0.32761531, -0.10120799],
#        [ 2.02998357, -0.02624934, -0.03718873],
#        [ 1.44777299, -1.78114568, -0.01620903]])

# %%
pca.components_.T # new reduced dimensions
# Out:
# array([[-0.50276537,  0.0435505 ,  0.03027479],
#        [-0.38473261,  0.4067255 , -0.34112831],
#        [-0.43967032,  0.25831283, -0.23916284],
#        [-0.33861501, -0.5848346 ,  0.45534023],
#        [-0.32629083, -0.60495574, -0.54334945],
#        [-0.42985112,  0.2407265 ,  0.56828927]])

# %%
X_t.shape
# Out:
# (70, 6)

# %%
pca.components_.T.shape
# Out:
# (6, 3)

# %%
np.dot(X_t, pca.components_.T)[:5] # pca.transform(X)
# Out:
# array([[ 1.27240098, -0.08152447, -0.44421778],
#        [ 1.24760651,  0.6289527 ,  0.13436957],
#        [ 0.59008376,  0.32761531, -0.10120799],
#        [ 2.02998357, -0.02624934, -0.03718873],
#        [ 1.44777299, -1.78114568, -0.01620903]])

# %%
df.head()
# Out:
#                     Flavour  Calories  ...  Protein (g)  cluster
# 0            Bananas Foster       160  ...          2.0        0
# 1              Baseball Nut       160  ...          3.0        0
# 2        Beavertails Pastry       170  ...          3.0        0
# 3  Blackberry Frozen Yogurt       120  ...          3.0        0
# 4    Blue Raspberry Sherbet       130  ...          2.0        2
#
# [5 rows x 8 columns]

# %%
dd=pd.concat([df, pd.DataFrame(pca.transform(X), 
                           columns=[f'PC{n}' for n in range(1, pca.n_components_ + 1)]), 
              ], axis = 'columns')
dd.head()
# Out:
#                     Flavour  Calories  ...        PC2       PC3
# 0            Bananas Foster       160  ... -10.620984  3.616899
# 1              Baseball Nut       160  ...  -7.573830  5.018768
# 2        Beavertails Pastry       170  ...  -9.492075  5.121581
# 3  Blackberry Frozen Yogurt       120  ... -12.020507  2.996606
# 4    Blue Raspberry Sherbet       130  ... -20.322514  5.337985
#
# [5 rows x 11 columns]

# %%
dd.cluster.unique().shape[0]
# Out:
# 3

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(data=dd, x='PC1', y='PC2', hue='cluster', 
                alpha=.8, palette=sns.color_palette("hls", df.cluster.unique().shape[0]), ax=ax)

# %% [markdown]
# ## **biplot using yellowbrick package**

# %% [markdown]
# ## **Plot 3 components**

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D

# %%
# pip install yellowbrick
import yellowbrick.features as yb
visualizer = yb.PCA(scale=True, proj_features=True, proj_dim=2)
visualizer.fit_transform(X)
visualizer.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-4c95e48b47e5> in <module>()
#       1 # pip install yellowbrick
#       2 import yellowbrick.features as yb
# ----> 3 visualizer = yb.PCA(scale=True, proj_features=True, proj_dim=2)
#       4 visualizer.fit_transform(X)
#       5 visualizer.show()
#
# AttributeError: module 'yellowbrick.features' has no attribute 'PCA'

# %%
# pca = PCA(n_components=X.shape[1])
pca = PCA(n_components=3)

X_pca=pca.fit_transform(X)
print(f'explained_variance (n_components={pca.n_components}) = {pca.explained_variance_}')
print(f'explained_variance_ratio (n_components={pca.n_components}) = {pca.explained_variance_ratio_}')
print(f'sum explained_variance_ratio = {np.sum(pca.explained_variance_ratio_)}')
# Out:
# explained_variance (n_components=3) = [3851.57952859   37.9262722    16.86334204]
# explained_variance_ratio (n_components=3) = [0.98358556 0.00968531 0.00430643]
# sum explained_variance_ratio = 0.9975772900849742

# %%
# switch to interactive matplotlib
# %matplotlib qt
# %pylab qt

# switch back to inline mode
# %matplotlib inline

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], alpha=.8, 
           c=df.cluster.map({0: 'r', 1: 'g', 2: 'b'}))

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3');
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-39-11980123f02d> in <module>()
#       1 # switch to interactive matplotlib
# ----> 2 get_ipython().magic('matplotlib qt')
#       3 get_ipython().magic('pylab qt')
#       4
#       5 # switch back to inline mode
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-98> in matplotlib(self, line)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    2948                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    2949
# -> 2950         pt.activate_matplotlib(backend)
#    2951         pt.configure_inline_support(self, backend)
#    2952
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     307
#     308     import matplotlib.pyplot
# --> 309     matplotlib.pyplot.switch_backend(backend)
#     310
#     311     # This must be imported last in the matplotlib series, after
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     219         else "matplotlib.backends.backend_{}".format(newbackend.lower()))
#     220
# --> 221     backend_mod = importlib.import_module(backend_name)
#     222     Backend = type(
#     223         "Backend", (matplotlib.backends._Backend,), vars(backend_mod))
#
# /usr/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_qt5agg.py in <module>()
#       9 from .. import cbook
#      10 from .backend_agg import FigureCanvasAgg
# ---> 11 from .backend_qt5 import (
#      12     QtCore, QtGui, QtWidgets, _BackendQT5, FigureCanvasQT, FigureManagerQT,
#      13     NavigationToolbar2QT, backend_version)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_qt5.py in <module>()
#      13     _Backend, FigureCanvasBase, FigureManagerBase, NavigationToolbar2,
#      14     TimerBase, cursors, ToolContainerBase, StatusbarBase, MouseButton)
# ---> 15 import matplotlib.backends.qt_editor.figureoptions as figureoptions
#      16 from matplotlib.backends.qt_editor.formsubplottool import UiSubplotTool
#      17 from matplotlib.backend_managers import ToolManager
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/qt_editor/figureoptions.py in <module>()
#      10 import matplotlib
#      11 from matplotlib import cbook, cm, colors as mcolors, markers, image as mimage
# ---> 12 from matplotlib.backends.qt_compat import QtGui
#      13 from matplotlib.backends.qt_editor import _formlayout
#      14
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/qt_compat.py in <module>()
#     166         break
#     167     else:
# --> 168         raise ImportError("Failed to import any qt binding")
#     169 else:  # We should not get there.
#     170     raise AssertionError("Unexpected QT_API: {}".format(QT_API))
#
# ImportError: Failed to import any qt binding
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
