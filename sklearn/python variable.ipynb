# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# *ตัวแปร String*

# %%
s='Hello World'
s1="Hello World"
s2="""I'm a student."""
print(s)
print(s1)
print(s2)

print(s[1:5])
# Out:
# Hello World
# Hello World
# I'm a student.
# ello

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b1c8228a-81fd-419d-ac1d-22e96a350ff5" name="files[]" multiple disabled />
#      <output id="result-b1c8228a-81fd-419d-ac1d-22e96a350ff5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.รายได้เฉลี่ยต่อเดือนต่อครัวเรือน 41-58.csv to 3.รายได้เฉลี่ยต่อเดือนต่อครัวเรือน 41-58.csv
# ...

# %%
f=open('3.รายได้เฉลี่ยต่อเดือนต่อครัวเรือน 41-58.csv',encoding='cp874')
for line in f:
  print(line)
f.close()
# Out:
# รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# Average Monthly Income Per Household: 1998 - 2015,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,บาท   Baht  ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ภาค และจังหวัด,,2541,2543,2545,2547,2549,2550,2552,2554,2556,2558,Region and province,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,(1998),(2000),(2002),(2004),(2006),(2007),(2009),(2011),(2013),(2015),,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
#  ทั่วราชอาณาจักร ,," 12,492 "," 12,150 "," 13,736 "," 14,963 "," 17,787 "," 18,660 "," 20,904 "," 23,236 "," 25,194 "," 26,915 ", Whole Kingdom ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ...
