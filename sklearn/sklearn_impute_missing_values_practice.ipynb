# %% [markdown]
# # Impute/Replace missing values

# %%
import pandas as pd
import numpy as np

# %%
print(f'pandas version: {pd.__version__}')
print(f'numpy  version: {np.__version__}')
# Out:
# pandas version: 1.1.5
# numpy  version: 1.19.5

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/msleep.csv')
df=df.sample(20, random_state=123)
df
# Out:
#                               name         genus  ...  brainwt   bodywt
# 69          Arctic ground squirrel  Spermophilus  ...  0.00570    0.920
# 75       Eastern american chipmunk        Tamias  ...      NaN    0.112
# 4                              Cow           Bos  ...  0.42300  600.000
# 78                      Tree shrew        Tupaia  ...  0.00250    0.104
# 29                         Giraffe       Giraffa  ...      NaN  899.995
# 62                      Rock hyrax      Procavia  ...  0.02100    3.600
# 24               European hedgehog     Erinaceus  ...  0.00350    0.770
# 37                         Macaque        Macaca  ...  0.17900    6.800
# 76                 Brazilian tapir       Tapirus  ...  0.16900  207.501
# 31                       Gray seal  Haliochoerus  ...  0.32500   85.000
# 8                              Dog         Canis  ...  0.07000   14.000
# 44                      Slow loris     Nyctibeus  ...  0.01250    1.400
# 9                         Roe deer     Capreolus  ...  0.09820   14.800
# 71  Golden-mantled ground squirrel  Spermophilus  ...      NaN    0.205
# 59                 Common porpoise      Phocoena  ...      NaN   53.180
# 70  Thirteen-lined ground squirrel  Spermophilus  ...  0.00400    0.101
# 23                          Donkey         Equus  ...  0.41900  187.000
# 19          North American Opossum     Didelphis  ...  0.00630    1.700
# 72                      Musk shrew        Suncus  ...  0.00033    0.048
# 81                      Arctic fox        Vulpes  ...  0.04450    3.380
#
# [20 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 69 to 81
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          20 non-null     object
#  1   genus         20 non-null     object
#  2   vore          18 non-null     object
#  3   order         20 non-null     object
#  4   conservation  14 non-null     object
#  5   sleep_total   20 non-null     float64
#  6   sleep_rem     14 non-null     float64
#  7   sleep_cycle   9 non-null      float64
#  8   awake         20 non-null     float64
#  9   brainwt       16 non-null     float64
#  10  bodywt        20 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 1.9+ KB

# %% [markdown]
# ## **check NA in 'vore' column**

# %%
df[df.vore.isna()]
# Out:
#           name     genus vore  ... awake  brainwt  bodywt
# 62  Rock hyrax  Procavia  NaN  ...  18.6  0.02100   3.600
# 72  Musk shrew    Suncus  NaN  ...  11.2  0.00033   0.048
#
# [2 rows x 11 columns]

# %% [markdown]
# ## **scikit-learn: SimpleImputer**

# %%
import sklearn
from sklearn.impute import SimpleImputer

# %%
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 0.22.2.post1

# %%
imp = SimpleImputer(strategy="most_frequent")
imp.fit_transform(df[['vore']])
# Out:
# array([['herbi'],
#        ['herbi'],
#        ['herbi'],
#        ['omni'],
#        ['herbi'],
#        ['herbi'],
#        ['omni'],
#        ['omni'],
#        ['herbi'],
#        ['carni'],
#        ['carni'],
#        ['carni'],
#        ['herbi'],
#        ['herbi'],
#        ['carni'],
#        ['herbi'],
#        ['herbi'],
#        ['omni'],
#        ['herbi'],
#        ['carni']], dtype=object)

# %%
df['vore2']=imp.fit_transform(df[['vore']])
df[df.vore.isna()][['name', 'vore', 'vore2']]
# Out:
#           name vore  vore2
# 62  Rock hyrax  NaN  herbi
# 72  Musk shrew  NaN  herbi

# %%
imp2 = SimpleImputer(strategy="constant", fill_value='omni')
df['vore3']=imp2.fit_transform(df[['vore']])
df[df.vore.isna()][['name', 'vore', 'vore2', 'vore3']]
# Out:
#           name vore  vore2 vore3
# 62  Rock hyrax  NaN  herbi  omni
# 72  Musk shrew  NaN  herbi  omni

# %%
df
# Out:
#                               name         genus   vore  ...   bodywt  vore2  vore3
# 69          Arctic ground squirrel  Spermophilus  herbi  ...    0.920  herbi  herbi
# 75       Eastern american chipmunk        Tamias  herbi  ...    0.112  herbi  herbi
# 4                              Cow           Bos  herbi  ...  600.000  herbi  herbi
# 78                      Tree shrew        Tupaia   omni  ...    0.104   omni   omni
# 29                         Giraffe       Giraffa  herbi  ...  899.995  herbi  herbi
# 62                      Rock hyrax      Procavia    NaN  ...    3.600  herbi   omni
# 24               European hedgehog     Erinaceus   omni  ...    0.770   omni   omni
# 37                         Macaque        Macaca   omni  ...    6.800   omni   omni
# 76                 Brazilian tapir       Tapirus  herbi  ...  207.501  herbi  herbi
# 31                       Gray seal  Haliochoerus  carni  ...   85.000  carni  carni
# 8                              Dog         Canis  carni  ...   14.000  carni  carni
# 44                      Slow loris     Nyctibeus  carni  ...    1.400  carni  carni
# 9                         Roe deer     Capreolus  herbi  ...   14.800  herbi  herbi
# 71  Golden-mantled ground squirrel  Spermophilus  herbi  ...    0.205  herbi  herbi
# 59                 Common porpoise      Phocoena  carni  ...   53.180  carni  carni
# 70  Thirteen-lined ground squirrel  Spermophilus  herbi  ...    0.101  herbi  herbi
# 23                          Donkey         Equus  herbi  ...  187.000  herbi  herbi
# 19          North American Opossum     Didelphis   omni  ...    1.700   omni   omni
# 72                      Musk shrew        Suncus    NaN  ...    0.048  herbi   omni
# 81                      Arctic fox        Vulpes  carni  ...    3.380  carni  carni
#
# [20 rows x 13 columns]

# %%
#imp3=SimpleImputer(strategy='mean')
#imp3=SimpleImputer(strategy='median')
imp3=SimpleImputer(strategy='constant', fill_value=-99)
df['sleep_rem4']=imp3.fit_transform(df[['sleep_rem']])
df[df.sleep_rem.isna()][['name', 'sleep_rem', 'sleep_rem4']]
#df[df.sleep_rem.isna()][['name', 'sleep_rem', 'sleep_rem2', 'sleep_rem3', 'sleep_rem4']]
# Out:
#                          name  sleep_rem  sleep_rem4
# 69     Arctic ground squirrel        NaN       -99.0
# 75  Eastern american chipmunk        NaN       -99.0
# 44                 Slow loris        NaN       -99.0
# 9                    Roe deer        NaN       -99.0
# 59            Common porpoise        NaN       -99.0
# 81                 Arctic fox        NaN       -99.0

# %%
#imp_x=SimpleImputer(strategy='mean')
#imp_x=SimpleImputer(strategy='median')
#imp_x=SimpleImputer(strategy='most_frequent')
imp_x=SimpleImputer(missing_values=-99, strategy='constant', fill_value=np.nan)

df['sleep_rem5']=imp_x.fit_transform(df[['sleep_rem4']])
df[df.sleep_rem4==-99.0][['name', 'sleep_rem4', 'sleep_rem5']]
# Out:
#                          name  sleep_rem4  sleep_rem5
# 69     Arctic ground squirrel       -99.0         NaN
# 75  Eastern american chipmunk       -99.0         NaN
# 44                 Slow loris       -99.0         NaN
# 9                    Roe deer       -99.0         NaN
# 59            Common porpoise       -99.0         NaN
# 81                 Arctic fox       -99.0         NaN

# %%
imp_x=SimpleImputer(strategy='mean')
#imp_x=SimpleImputer(strategy='median')
#imp_x=SimpleImputer(strategy='most_frequent')
#imp_x=SimpleImputer(missing_values=-99, strategy='constant', fill_value=np.nan)

df['sleep_rem6']=imp_x.fit_transform(df[['sleep_rem5']])
df[df.sleep_rem5.isna()][['name', 'sleep_rem4', 'sleep_rem5', 'sleep_rem6']]
# Out:
#                          name  sleep_rem4  sleep_rem5  sleep_rem6
# 69     Arctic ground squirrel       -99.0         NaN         2.0
# 75  Eastern american chipmunk       -99.0         NaN         2.0
# 44                 Slow loris       -99.0         NaN         2.0
# 9                    Roe deer       -99.0         NaN         2.0
# 59            Common porpoise       -99.0         NaN         2.0
# 81                 Arctic fox       -99.0         NaN         2.0
