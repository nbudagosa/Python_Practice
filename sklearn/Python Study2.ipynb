# %% [markdown]
# ### **Intro to Python**
# This is my first lesson on Python!

# %%
# print hello world to console
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### **Foundations**
# * Variable
# * Data Type
# * Data Structure
# * Control Flow
# * Function

# %%
print(1 + 1)
print(2 - 4)
print(3 * 5)
print(5 / 2)
# Out:
# 2
# -2
# 15
# 2.5

# %%
print("Hello World")
print('Hello World')
print("""Longggggggggggggggggggggggggggg
      STRING
      MULTIPLE Lines""")
# Out:
# Hello World
# Hello World
# Longggggggggggggggggggggggggggg
#       STRING
#       MULTIPLE Lines

# %%
print(100 == 100)
print("hello" == "hello")
# Out:
# True
# True

# %%
## create variables
income = 50000
expense = 38000
print(income)
print(expense)
# Out:
# 50000
# 38000

# %%
saving = income - expense
print(saving)
# Out:
# 12000

# %%
my_name = "Toy"
my_age = 31

# %%
print(my_name)
print(my_age)
# Out:
# Toy
# 31
